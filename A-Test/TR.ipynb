# %% [markdown]
# ## Step1 导入相关包

# %%
import transformers
from transformers import AutoTokenizer,MistralForCausalLM,LlamaTokenizer,AutoConfig
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import transformers
#       2 from transformers import AutoTokenizer,MistralForCausalLM,LlamaTokenizer,AutoConfig
#
# ModuleNotFoundError: No module named 'transformers'

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## 参数初始化｜｜加载模型

# %%
model_pth = "/home/data/hhj/Model/Mistral"
to = LlamaTokenizer.from_pretrained("/home/data/hhj/Model/Mistral")
# model = MistralForCausalLM.from_pretrained(model_pth)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 model_pth = "/home/data/hhj/Model/Mistral"
# ----> 2 to = LlamaTokenizer.from_pretrained("/home/data/hhj/Model/Mistral")
#       3 # model = MistralForCausalLM.from_pretrained(model_pth)
#
# File /home/data/hhj/anaconda3/envs/mistral/lib/python3.12/site-packages/transformers/utils/import_utils.py:2157, in DummyObject.__getattribute__(cls, key)
#    2155 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2156     return super().__getattribute__(key)
# -> 2157 requires_backends(cls, cls._backends)
#
# File /home/data/hhj/anaconda3/envs/mistral/lib/python3.12/site-packages/transformers/utils/import_utils.py:2143, in requires_backends(obj, backends)
#    2140         failed.append(msg.format(name))
#    2142 if failed:
# ...

# %%
config = AutoConfig.from_pretrained(model_pth)
config
# Out:
# MistralConfig {
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "dtype": "bfloat16",
#   "eos_token_id": 2,
#   "head_dim": null,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "rms_norm_eps": 1e-05,
#   "rope_theta": 10000.0,
#   "sliding_window": 4096,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.57.1",
#   "use_cache": false,
#   "vocab_size": 32001
# }

# %%
import torchvision
